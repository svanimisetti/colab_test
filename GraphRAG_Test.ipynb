# %% [markdown]
# <a href="https://colab.research.google.com/github/svanimisetti/colab_test/blob/main/GraphRAG_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
a=2

# %%
b=2*a
print(b)
# Out:
# 4

# %% [markdown]
# # New Section

# %%
c=5

# %%
d=c**2
print(d)
# Out:
# 25
